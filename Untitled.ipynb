# %%
import pandas as pd

# %%
cd /users/admin/dropbox/dataprojects/epl/exports
# Out:
# /Users/admin/Dropbox/DataProjects/epl/exports

# %%
df = pd.read_csv("2017-12-03_df.csv")

# %%
df
# Out:
#      Unnamed: 0 team  Goals  Assists  Shots  Shots on Goal  Saves  \
# 0             1  ARS      4        4     27             10      0
# 1             2  LEI      3        3      6              3      6
# 2             3  BHA      0        0      6              2      3
# 3             4  MCI      2        1     14              4      2
# 4             5  CRY      0        0     14              4      4
# 5             6  HUD      3        2      8              6      4
# 6             7  EVE      1        1      9              4      1
# 7             8  STK      0        0      9              1      3
# 8             9  SOU      0        0     29              2      0
# 9            10  SWA      0        0      4              0      2
# 10           11  WAT      3        1      9              4      2
# 11           12  LIV      3        2     14              5      1
# 12           13  WBA      1        1     16              6      2
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame
